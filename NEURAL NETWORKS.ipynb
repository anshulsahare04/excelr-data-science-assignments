# %% [markdown]
# ## ARTIFICIAL NEURAL NETWORKS

# %% [raw]
# Classification Using Artificial Neural Networks with Hyperparameter Tuning on Alphabets Data
#
# Tasks
# 1. Data Exploration and Preprocessing
# ●	Begin by loading and exploring the "Alphabets_data.csv" dataset. Summarize its key features such as the number of samples, features, and classes.
# ●	Execute necessary data preprocessing steps including data normalization, managing missing values.
#
# 2. Model Implementation
# ●	Construct a basic ANN model using your chosen high-level neural network library. Ensure your model includes at least one hidden layer.
# ●	Divide the dataset into training and test sets.
# ●	Train your model on the training set and then use it to make predictions on the test set.
#
# 3. Hyperparameter Tuning
# ●	Modify various hyperparameters, such as the number of hidden layers, neurons per hidden layer, activation functions, and learning rate, to observe their impact on model performance.
# ●	Adopt a structured approach like grid search or random search for hyperparameter tuning, documenting your methodology thoroughly.
#
# 4. Evaluation
# ●	Employ suitable metrics such as accuracy, precision, recall, and F1-score to evaluate your model's performance.
# ●	Discuss the performance differences between the model with default hyperparameters and the tuned model, emphasizing the effects of hyperparameter tuning.
#
# Evaluation Criteria
# ●	Accuracy and completeness of the implementation.
# ●	Proficiency in data preprocessing and model development.
# ●	Systematic approach and thoroughness in hyperparameter tuning.
# ●	Depth of evaluation and discussion.
# ●	Overall quality of the report.

# %% [markdown]
# ### 1. Data Exploration and Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
df=pd.read_csv('Alphabets_data.csv')

# %%
df
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          T     2     8      3       5      1     8    13      0      6
# 1          I     5    12      3       7      2    10     5      5      4
# 2          D     4    11      6       8      6    10     6      2      6
# 3          N     7    11      6       6      3     5     9      4      6
# 4          G     2     1      3       1      1     8     6      6      6
# ...      ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19995      D     2     2      3       3      2     7     7      7      6
# 19996      C     7    10      8       8      4     4     8      6      9
# 19997      T     6     9      6       7      5     6    11      3      7
# 19998      S     2     3      4       2      1     8     7      2      6
# 19999      A     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0          6      10       8      0       8      0       8
# 1         13       3       9      2       8      4      10
# 2         10       3       7      3       7      3       9
# 3          4       4      10      6      10      2       8
# 4          6       5       9      1       7      5      10
# ...      ...     ...     ...    ...     ...    ...     ...
# 19995      6       6       4      2       8      3       7
# 19996     12       9      13      2       9      3       7
# 19997     11       9       5      2      12      2       4
# 19998     10       6       8      1       9      5       8
# 19999      8       1       8      2       7      2       8
#
# [20000 rows x 17 columns]

# %%
df.shape
# Out:
# (20000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  object
#  1   xbox    20000 non-null  int64
#  2   ybox    20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   xbar    20000 non-null  int64
#  7   ybar    20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybar  20000 non-null  int64
#  12  xy2bar  20000 non-null  int64
#  13  xedge   20000 non-null  int64
#  14  xedgey  20000 non-null  int64
#  15  yedge   20000 non-null  int64
#  16  yedgex  20000 non-null  int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB

# %%
#Check for missing values

print(df.isnull().sum())
# Out:
# letter    0
# xbox      0
# ybox      0
# width     0
# height    0
# onpix     0
# xbar      0
# ybar      0
# x2bar     0
# y2bar     0
# xybar     0
# x2ybar    0
# xy2bar    0
# xedge     0
# xedgey    0
# yedge     0
# yedgex    0
# dtype: int64

# %%
df.describe()
# Out:
#                xbox          ybox         width       height         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#                xbar          ybar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# std        2.026035      2.325354      2.699968      2.380823      2.488475
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000      6.000000      3.000000      4.000000      7.000000
# 50%        7.000000      7.000000      4.000000      5.000000      8.000000
# 75%        8.000000      9.000000      6.000000      7.000000     10.000000
# max       15.000000     15.000000     15.000000     15.000000     15.000000
#
#             x2ybar        xy2bar         xedge        xedgey         yedge  \
# count  20000.00000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.45400      7.929000      3.046100      8.338850      3.691750
# std        2.63107      2.080619      2.332541      1.546722      2.567073
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 25%        5.00000      7.000000      1.000000      8.000000      2.000000
# 50%        6.00000      8.000000      3.000000      8.000000      3.000000
# 75%        8.00000      9.000000      4.000000      9.000000      5.000000
# max       15.00000     15.000000     15.000000     15.000000     15.000000
#
#             yedgex
# count  20000.00000
# mean       7.80120
# std        1.61747
# min        0.00000
# 25%        7.00000
# 50%        8.00000
# 75%        9.00000
# max       15.00000

# %%
# Encode categorical variables if necessary
label_encoder = LabelEncoder()
df['letter'] = label_encoder.fit_transform(df['letter'])

# %%
# Separate features and target variable
x = df.drop(columns=['letter'])   #feature
y = df['letter']                  #target

# %%
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
X_scaled = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# %%
feature_scaled = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(feature_scaled,y, test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (16000, 16)
# (4000, 16)
# (16000,)
# (4000,)

# %% [markdown]
# ### 2. Model Implementation

# %%
model = Sequential()
model
# Out:
# <Sequential name=sequential, built=False>

# %%
model.add(Dense(64,activation='relu',input_shape=(x_train.shape[1],)))    #Input Layer

model.add(Dense(32, activation='relu'))  # Hidden layer

model.add(Dense(len(y.unique()), activation='softmax'))  # Output layer for multi-class classification

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])     # Compile the model
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#Train the model

history = model.fit(x_train, y_train, epochs=50, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2627 - loss: 2.6696 - val_accuracy: 0.6653 - val_loss: 1.2085
# Epoch 2/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7007 - loss: 1.0531 - val_accuracy: 0.7472 - val_loss: 0.8842
# Epoch 3/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7686 - loss: 0.8008 - val_accuracy: 0.7928 - val_loss: 0.7326
# Epoch 4/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8074 - loss: 0.6685 - val_accuracy: 0.8059 - val_loss: 0.6574
# Epoch 5/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8205 - loss: 0.6108 - val_accuracy: 0.8272 - val_loss: 0.5926
# Epoch 6/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8403 - loss: 0.5444 - val_accuracy: 0.8434 - val_loss: 0.5368
# Epoch 7/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8592 - loss: 0.4959 - val_accuracy: 0.8509 - val_loss: 0.5061
# Epoch 8/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8638 - loss: 0.4594 - val_accuracy: 0.8537 - val_loss: 0.4758
# Epoch 9/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8775 - loss: 0.4067 - val_accuracy: 0.8719 - val_loss: 0.4440
# Epoch 10/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8789 - loss: 0.3892 - val_accuracy: 0.8744 - val_loss: 0.4186
# Epoch 11/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8874 - loss: 0.3670 - val_accuracy: 0.8816 - val_loss: 0.3976
# Epoch 12/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8966 - loss: 0.3388 - val_accuracy: 0.8809 - val_loss: 0.3901
# Epoch 13/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9007 - loss: 0.3191 - val_accuracy: 0.8866 - val_loss: 0.3673
# Epoch 14/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9033 - loss: 0.3148 - val_accuracy: 0.8919 - val_loss: 0.3546
# Epoch 15/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9121 - loss: 0.2868 - val_accuracy: 0.8941 - val_loss: 0.3495
# Epoch 16/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9094 - loss: 0.2862 - val_accuracy: 0.9025 - val_loss: 0.3303
# Epoch 17/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9163 - loss: 0.2583 - val_accuracy: 0.9050 - val_loss: 0.3181
# Epoch 18/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9225 - loss: 0.2492 - val_accuracy: 0.9084 - val_loss: 0.3106
# Epoch 19/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9244 - loss: 0.2402 - val_accuracy: 0.9019 - val_loss: 0.3094
# Epoch 20/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9280 - loss: 0.2289 - val_accuracy: 0.9109 - val_loss: 0.2930
# Epoch 21/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9312 - loss: 0.2190 - val_accuracy: 0.9141 - val_loss: 0.2835
# Epoch 22/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9365 - loss: 0.2039 - val_accuracy: 0.9112 - val_loss: 0.2820
# Epoch 23/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9391 - loss: 0.2015 - val_accuracy: 0.9187 - val_loss: 0.2719
# Epoch 24/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9432 - loss: 0.1898 - val_accuracy: 0.9109 - val_loss: 0.2811
# Epoch 25/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9410 - loss: 0.1858 - val_accuracy: 0.9175 - val_loss: 0.2675
# Epoch 26/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9436 - loss: 0.1810 - val_accuracy: 0.9184 - val_loss: 0.2636
# Epoch 27/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9452 - loss: 0.1745 - val_accuracy: 0.9209 - val_loss: 0.2631
# Epoch 28/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9424 - loss: 0.1747 - val_accuracy: 0.9169 - val_loss: 0.2639
# Epoch 29/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9499 - loss: 0.1663 - val_accuracy: 0.9203 - val_loss: 0.2523
# Epoch 30/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9511 - loss: 0.1580 - val_accuracy: 0.9219 - val_loss: 0.2506
# Epoch 31/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9529 - loss: 0.1540 - val_accuracy: 0.9275 - val_loss: 0.2481
# Epoch 32/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9560 - loss: 0.1477 - val_accuracy: 0.9250 - val_loss: 0.2413
# Epoch 33/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9574 - loss: 0.1461 - val_accuracy: 0.9256 - val_loss: 0.2411
# Epoch 34/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9581 - loss: 0.1410 - val_accuracy: 0.9225 - val_loss: 0.2449
# Epoch 35/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9595 - loss: 0.1328 - val_accuracy: 0.9234 - val_loss: 0.2413
# Epoch 36/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9609 - loss: 0.1317 - val_accuracy: 0.9306 - val_loss: 0.2401
# Epoch 37/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9587 - loss: 0.1342 - val_accuracy: 0.9266 - val_loss: 0.2405
# Epoch 38/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9607 - loss: 0.1286 - val_accuracy: 0.9300 - val_loss: 0.2338
# Epoch 39/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9614 - loss: 0.1256 - val_accuracy: 0.9322 - val_loss: 0.2271
# Epoch 40/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9653 - loss: 0.1184 - val_accuracy: 0.9250 - val_loss: 0.2325
# Epoch 41/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9691 - loss: 0.1078 - val_accuracy: 0.9256 - val_loss: 0.2370
# Epoch 42/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9639 - loss: 0.1148 - val_accuracy: 0.9322 - val_loss: 0.2287
# Epoch 43/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9669 - loss: 0.1146 - val_accuracy: 0.9328 - val_loss: 0.2290
# Epoch 44/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9673 - loss: 0.1142 - val_accuracy: 0.9369 - val_loss: 0.2235
# Epoch 45/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9690 - loss: 0.1088 - val_accuracy: 0.9319 - val_loss: 0.2296
# Epoch 46/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9704 - loss: 0.1056 - val_accuracy: 0.9272 - val_loss: 0.2412
# Epoch 47/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9688 - loss: 0.1050 - val_accuracy: 0.9378 - val_loss: 0.2191
# Epoch 48/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9741 - loss: 0.0925 - val_accuracy: 0.9287 - val_loss: 0.2343
# Epoch 49/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9701 - loss: 0.0946 - val_accuracy: 0.9341 - val_loss: 0.2295
# Epoch 50/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9700 - loss: 0.0949 - val_accuracy: 0.9312 - val_loss: 0.2344

# %% [markdown]
# ### 3. Hyperparameter Tuning

# %%
pip install tensorflow scikit-learn pandas
# Out:
# Requirement already satisfied: tensorflow in c:\users\hp\anaconda3\lib\site-packages (2.18.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scikit-learn in c:\users\hp\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (25.1.21)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.69.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hp\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\hp\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\hp\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\hp\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\hp\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)

# %%
pip install scikeras
# Out:
# Requirement already satisfied: scikeras in c:\users\hp\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\hp\anaconda3\lib\site-packages (from scikeras) (3.8.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in c:\users\hp\anaconda3\lib\site-packages (from scikeras) (1.5.1)
# Requirement already satisfied: absl-py in c:\users\hp\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in c:\users\hp\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (13.7.1)
# Requirement already satisfied: namex in c:\users\hp\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\hp\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (3.11.0)
# Requirement already satisfied: optree in c:\users\hp\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (0.14.0)
# Requirement already satisfied: ml-dtypes in c:\users\hp\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (24.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\hp\anaconda3\lib\site-packages (from optree->keras>=3.2.0->scikeras) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\anaconda3\lib\site-packages (from rich->keras>=3.2.0->scikeras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\anaconda3\lib\site-packages (from rich->keras>=3.2.0->scikeras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\hp\anaconda3\lib\site-packages (1.4.7)
# Requirement already satisfied: keras in c:\users\hp\anaconda3\lib\site-packages (from keras-tuner) (3.8.0)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from keras-tuner) (24.1)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from keras-tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in c:\users\hp\anaconda3\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in c:\users\hp\anaconda3\lib\site-packages (from keras->keras-tuner) (2.1.0)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in c:\users\hp\anaconda3\lib\site-packages (from keras->keras-tuner) (13.7.1)
# Requirement already satisfied: namex in c:\users\hp\anaconda3\lib\site-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in c:\users\hp\anaconda3\lib\site-packages (from keras->keras-tuner) (3.11.0)
# Requirement already satisfied: optree in c:\users\hp\anaconda3\lib\site-packages (from keras->keras-tuner) (0.14.0)
# Requirement already satisfied: ml-dtypes in c:\users\hp\anaconda3\lib\site-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->keras-tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->keras-tuner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests->keras-tuner) (2024.12.14)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\hp\anaconda3\lib\site-packages (from optree->keras->keras-tuner) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\anaconda3\lib\site-packages (from rich->keras->keras-tuner) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\anaconda3\lib\site-packages (from rich->keras->keras-tuner) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras_tuner import RandomSearch
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\hp\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (25.1.21)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.69.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hp\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\hp\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\hp\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\hp\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\hp\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from kerastuner import RandomSearch

def build_model(hp):
    model = Sequential()
    model.add(Dense(units=hp.Int('units1', min_value=32, max_value=128, step=16), activation='relu', input_shape=(x_train.shape[1],)))
    model.add(Dense(units=hp.Int('units2', min_value=16, max_value=64, step=16), activation='relu'))
    model.add(Dense(len(label_encoder.classes_), activation='softmax'))
    
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
tuner = RandomSearch(build_model, objective='val_accuracy', max_trials=5, executions_per_trial=3)

tuner.search(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Trial 5 Complete [00h 02m 00s]
# val_accuracy: 0.8458333214124044
#
# Best val_accuracy So Far: 0.9337499936421713
# Total elapsed time: 00h 10m 24s

# %%
# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Best units1: {best_hps.get('units1')}, Best units2: {best_hps.get('units2')}, Best learning_rate: {best_hps.get('learning_rate')}")
# Out:
# Best units1: 48, Best units2: 32, Best learning_rate: 0.001

# %%
# Build the best model with optimal hyperparameters
best_model = tuner.hypermodel.build(best_hps)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train the model
best_model.fit(x_train, y_train, epochs=50, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2395 - loss: 2.7311 - val_accuracy: 0.6506 - val_loss: 1.2778
# Epoch 2/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6862 - loss: 1.1187 - val_accuracy: 0.7266 - val_loss: 0.9393
# Epoch 3/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7499 - loss: 0.8451 - val_accuracy: 0.7719 - val_loss: 0.8012
# Epoch 4/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7920 - loss: 0.7261 - val_accuracy: 0.7969 - val_loss: 0.7117
# Epoch 5/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8070 - loss: 0.6546 - val_accuracy: 0.8094 - val_loss: 0.6484
# Epoch 6/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8304 - loss: 0.5853 - val_accuracy: 0.8284 - val_loss: 0.5972
# Epoch 7/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8419 - loss: 0.5369 - val_accuracy: 0.8359 - val_loss: 0.5565
# Epoch 8/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8556 - loss: 0.4929 - val_accuracy: 0.8500 - val_loss: 0.5203
# Epoch 9/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8634 - loss: 0.4690 - val_accuracy: 0.8525 - val_loss: 0.4906
# Epoch 10/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8687 - loss: 0.4302 - val_accuracy: 0.8594 - val_loss: 0.4661
# Epoch 11/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8879 - loss: 0.3861 - val_accuracy: 0.8675 - val_loss: 0.4381
# Epoch 12/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8893 - loss: 0.3714 - val_accuracy: 0.8734 - val_loss: 0.4210
# Epoch 13/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8924 - loss: 0.3564 - val_accuracy: 0.8791 - val_loss: 0.4034
# Epoch 14/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9026 - loss: 0.3340 - val_accuracy: 0.8872 - val_loss: 0.3845
# Epoch 15/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9086 - loss: 0.3159 - val_accuracy: 0.8900 - val_loss: 0.3649
# Epoch 16/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9070 - loss: 0.2993 - val_accuracy: 0.8919 - val_loss: 0.3623
# Epoch 17/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9151 - loss: 0.2873 - val_accuracy: 0.8966 - val_loss: 0.3432
# Epoch 18/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9160 - loss: 0.2854 - val_accuracy: 0.9000 - val_loss: 0.3343
# Epoch 19/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9185 - loss: 0.2628 - val_accuracy: 0.9031 - val_loss: 0.3262
# Epoch 20/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9218 - loss: 0.2570 - val_accuracy: 0.9038 - val_loss: 0.3148
# Epoch 21/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9245 - loss: 0.2504 - val_accuracy: 0.9034 - val_loss: 0.3208
# Epoch 22/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9238 - loss: 0.2433 - val_accuracy: 0.9100 - val_loss: 0.2971
# Epoch 23/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9311 - loss: 0.2232 - val_accuracy: 0.9100 - val_loss: 0.2931
# Epoch 24/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9356 - loss: 0.2183 - val_accuracy: 0.9100 - val_loss: 0.3011
# Epoch 25/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9334 - loss: 0.2181 - val_accuracy: 0.9097 - val_loss: 0.2865
# Epoch 26/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9355 - loss: 0.2048 - val_accuracy: 0.9112 - val_loss: 0.2803
# Epoch 27/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9396 - loss: 0.1962 - val_accuracy: 0.9150 - val_loss: 0.2788
# Epoch 28/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9414 - loss: 0.1939 - val_accuracy: 0.9178 - val_loss: 0.2705
# Epoch 29/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9376 - loss: 0.1952 - val_accuracy: 0.9178 - val_loss: 0.2687
# Epoch 30/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9440 - loss: 0.1770 - val_accuracy: 0.9153 - val_loss: 0.2688
# Epoch 31/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9417 - loss: 0.1807 - val_accuracy: 0.9159 - val_loss: 0.2722
# Epoch 32/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9447 - loss: 0.1758 - val_accuracy: 0.9187 - val_loss: 0.2618
# Epoch 33/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9485 - loss: 0.1623 - val_accuracy: 0.9178 - val_loss: 0.2651
# Epoch 34/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9467 - loss: 0.1720 - val_accuracy: 0.9172 - val_loss: 0.2639
# Epoch 35/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9529 - loss: 0.1565 - val_accuracy: 0.9262 - val_loss: 0.2533
# Epoch 36/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9503 - loss: 0.1547 - val_accuracy: 0.9212 - val_loss: 0.2534
# Epoch 37/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9494 - loss: 0.1604 - val_accuracy: 0.9162 - val_loss: 0.2605
# Epoch 38/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9562 - loss: 0.1421 - val_accuracy: 0.9241 - val_loss: 0.2519
# Epoch 39/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9535 - loss: 0.1476 - val_accuracy: 0.9256 - val_loss: 0.2413
# Epoch 40/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9557 - loss: 0.1388 - val_accuracy: 0.9281 - val_loss: 0.2376
# Epoch 41/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9550 - loss: 0.1434 - val_accuracy: 0.9269 - val_loss: 0.2393
# Epoch 42/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9561 - loss: 0.1340 - val_accuracy: 0.9237 - val_loss: 0.2452
# Epoch 43/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9612 - loss: 0.1257 - val_accuracy: 0.9316 - val_loss: 0.2394
# Epoch 44/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9575 - loss: 0.1346 - val_accuracy: 0.9275 - val_loss: 0.2377
# Epoch 45/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9577 - loss: 0.1311 - val_accuracy: 0.9300 - val_loss: 0.2319
# Epoch 46/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9605 - loss: 0.1227 - val_accuracy: 0.9306 - val_loss: 0.2400
# Epoch 47/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9618 - loss: 0.1215 - val_accuracy: 0.9294 - val_loss: 0.2352
# Epoch 48/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9612 - loss: 0.1165 - val_accuracy: 0.9287 - val_loss: 0.2347
# Epoch 49/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9624 - loss: 0.1204 - val_accuracy: 0.9303 - val_loss: 0.2317
# Epoch 50/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9622 - loss: 0.1187 - val_accuracy: 0.9306 - val_loss: 0.2351

# %%
# Evaluate the model
test_loss, test_accuracy = best_model.evaluate(x_test, y_test)
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - accuracy: 0.9346 - loss: 0.2091
# Test Accuracy: 0.9380000233650208
